# %% [markdown]
# <a href="https://colab.research.google.com/github/minoooo119/deeplearning_study/blob/main/doit_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🧰 딥러닝 위한 도구

# %% [markdown]
# ## 🥇 넘파이

# %%
import numpy as np
print(np.__version__)
# Out:
# 1.22.4

# %%
my_arr=np.array([[10,20,30],[40,50,60]])
print(my_arr)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
type(my_arr) #type 확인
# Out:
# numpy.ndarray

# %%
np.sum(my_arr)  #numpy 내장 함수, 모든 요소 합
# Out:
# 210

# %% [markdown]
# ## 🥈 맷플롯립

# %%
#맷플롯립으로 그래프 그리기
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4,5],[1,4,9,16,25]) #x,y 축의 값을 파이썬 리스트로 전달
plt.show() #화면에 그래프 출력 y=x^2 그래프임
##1. 선그래프 그리기

# %%
##2. 산점도 그리기 (scatter plot)
plt.scatter([1,2,3,4,5],[1,4,9,16,25])
plt.show()

# %%
#3. 넘파이 배열로 산점도 그리기
#1000개의 난수를 만들어 산점도 그림
x=np.random.randn(1000)
y=np.random.randn(1000)
plt.scatter(x,y)
plt.show()

# %%
#기초 지식임 다음으로 딥러닝
